# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import seaborn as sns
from skimpy import clean_columns
from wordcloud import WordCloud
from my_functions import *

# %%
# Display float with 2 decimal values
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Get & Inspect the data

# %%
raw = pd.read_csv("https://pythonandvba.com/youtube-data.csv")

# %%
# Sample the data
raw.sample(5)
# Out:
#          Content                                        Video title  \
# 102  ldJR61FLhqw  How To Create A GUI Program In Python Using Tk...
# 32   LzCfNanQ_9c  Create an advanced GUI app with PySimpleGUI (F...
# 9    xE95tIzCuKM  Turn Your Excel Data Into An Interactive Dashb...
# 86   EvvmOVyQaVY  Automate Tinder with EXCEL | Step-By-Step Tuto...
# 24   ZI9T2O7XYxY  Solve Real-World Data Science Tasks in Python ...
#
#     Video publish time  Comments added  Average percentage viewed (%)  Likes  \
# 102          13-Sep-20               3                          31.51     46
# 32           17-Jul-22              31                          12.62    424
# 9            27-Mar-22              64                          18.92    896
# 86           25-Sep-21               7                          17.39     45
# 24           31-Jan-21              40                          14.59    414
#
#      Views  Impressions  Impressions click-through rate (%)
# 102   1994        37525                                3.43
# 32   12537       164553                                4.69
# 9    24612       541894                                2.23
# 86    1343        26336                                2.67
# 24   12911       133624                                5.22

# %%
# Get an overview of the data
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Content                             107 non-null    object
#  1   Video title                         107 non-null    object
#  2   Video publish time                  102 non-null    object
#  3   Comments added                      107 non-null    int64
#  4   Average percentage viewed (%)       107 non-null    float64
#  5   Likes                               107 non-null    int64
#  6   Views                               107 non-null    int64
#  7   Impressions                         107 non-null    int64
#  8   Impressions click-through rate (%)  106 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 7.6+ KB

# %%
# Check missing values
missing_values_table(raw)
# Out:
# Dein Datensatz hat 9 columns.
# Es gibt 2 Spalten mit missing values.
#                                     Missing Values  % of Total Values
# Video publish time                               5               4.70
# Impressions click-through rate (%)               1               0.90

# %%
# Display rows with missing values
raw[raw.isnull().any(axis="columns")]
# Out:
#          Content                                        Video title  \
# 94   8E4se9Ah5o8                            MyToolBelt Installation
# 96   V3Csrk--laM                            Create Invoice Filepath
# 100  RnTqlKzQhRY                          PySimpleGUI Retrieve Data
# 105  l4Dd1xLfNVY                                     xlwings - demo
# 106  pqIjey6Cbhw  How to resolve "pytube.exceptions.RegexMatchEr...
#
#     Video publish time  Comments added  Average percentage viewed (%)  Likes  \
# 94                 NaN               5                          72.18     22
# 96                 NaN               5                          70.11      1
# 100                NaN               4                          85.97      6
# 105                NaN               0                         102.23      0
# 106                NaN               0                          44.91      0
#
#      Views  Impressions  Impressions click-through rate (%)
# 94    1309           13                                0.00
# 96      16            5                                0.00
# 100    182           78                                2.56
# 105      3            0                                 NaN
# 106     13            3                                0.00

# %%
# Generate descriptive statistics
raw.describe().T
# Out:
#                                     count      mean        std   min      25%  \
# Comments added                     107.00     37.24      89.53  0.00     8.50
# Average percentage viewed (%)      107.00     33.75      16.57 12.62    23.55
# Likes                              107.00    417.86    1081.01  0.00    92.50
# Views                              107.00  17792.68   50709.27  3.00  2582.00
# Impressions                        107.00 249785.20 1133091.96  0.00 43961.00
# Impressions click-through rate (%) 106.00      4.46       2.06  0.00     3.06
#
#                                         50%       75%         max
# Comments added                        21.00     33.50      885.00
# Average percentage viewed (%)         28.91     38.79      102.23
# Likes                                203.00    352.50    10175.00
# Views                               6382.00  12968.50   442044.00
# Impressions                        79838.00 132846.50 11550064.00
# Impressions click-through rate (%)     4.17      5.73       10.86

# %%
# Inspect highest average percentage viewed
raw.nlargest(5, columns=["Average percentage viewed (%)"])
# Out:
#          Content                                        Video title  \
# 105  l4Dd1xLfNVY                                     xlwings - demo
# 100  RnTqlKzQhRY                          PySimpleGUI Retrieve Data
# 89   HYl-gftg9Rw  How To Save Cookies & Login Data In Selenium V...
# 75   0_HlInz6HuM  How To Remove “Made with Streamlit”, Hamburger...
# 99   JaPj_gOTg6M  Pull Stock Data & Export It To Excel Using Pyt...
#
#     Video publish time  Comments added  Average percentage viewed (%)  Likes  \
# 105                NaN               0                         102.23      0
# 100                NaN               4                          85.97      6
# 89           21-Sep-21               6                          81.96     46
# 75           22-Jul-21              10                          78.33    115
# 99            6-Mar-21               4                          73.26     89
#
#      Views  Impressions  Impressions click-through rate (%)
# 105      3            0                                 NaN
# 100    182           78                                2.56
# 89    2436          325                                3.38
# 75    3708        31197                                3.57
# 99    1961        37686                                2.76

# %%
# Most features (columns) are showing a difference between mean <> median
# This indicates that the data is skewed
hist = raw.hist(bins=15, figsize=(16,10))

# %%
# Plot heatmap
heatmap = sns.heatmap(raw.corr(), cmap="BuPu", annot=True, fmt=".3f")
# Out:
# C:\Users\jan.lade\AppData\Local\Temp\ipykernel_3640\3249054074.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(raw.corr(), cmap="BuPu", annot=True, fmt=".3f")

# %%
# Check correlation of the features (columns)
(raw
 .corr()
 .style
 .background_gradient(cmap='RdBu', vmin=-1, vmax=1)
)
# Out:
# C:\Users\jan.lade\AppData\Local\Temp\ipykernel_3640\331218267.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   .corr()
# <style type="text/css">
# #T_0b9f8_row0_col0, #T_0b9f8_row1_col1, #T_0b9f8_row2_col2, #T_0b9f8_row3_col3, #T_0b9f8_row4_col4, #T_0b9f8_row5_col5 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_0b9f8_row0_col1, #T_0b9f8_row1_col0 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_0b9f8_row0_col2, #T_0b9f8_row2_col0 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_0b9f8_row0_col3, #T_0b9f8_row3_col0 {
#   background-color: #3681ba;
#   color: #f1f1f1;
# }
# #T_0b9f8_row0_col4, #T_0b9f8_row4_col0 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_0b9f8_row0_col5, #T_0b9f8_row5_col0 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_0b9f8_row1_col2, #T_0b9f8_row2_col1 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_0b9f8_row1_col3, #T_0b9f8_row3_col1 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_0b9f8_row1_col4, #T_0b9f8_row4_col1 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_0b9f8_row1_col5, #T_0b9f8_row5_col1 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_0b9f8_row2_col3, #T_0b9f8_row2_col4, #T_0b9f8_row3_col2, #T_0b9f8_row4_col2 {
#   background-color: #0a3b70;
#   color: #f1f1f1;
# }
# #T_0b9f8_row2_col5, #T_0b9f8_row5_col2 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_0b9f8_row3_col4, #T_0b9f8_row4_col3 {
#   background-color: #0f437b;
#   color: #f1f1f1;
# }
# #T_0b9f8_row3_col5, #T_0b9f8_row5_col3 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_0b9f8_row4_col5, #T_0b9f8_row5_col4 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# </style>
# <table id="T_0b9f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b9f8_level0_col0" class="col_heading level0 col0" >Comments added</th>
#       <th id="T_0b9f8_level0_col1" class="col_heading level0 col1" >Average percentage viewed (%)</th>
#       <th id="T_0b9f8_level0_col2" class="col_heading level0 col2" >Likes</th>
#       <th id="T_0b9f8_level0_col3" class="col_heading level0 col3" >Views</th>
#       <th id="T_0b9f8_level0_col4" class="col_heading level0 col4" >Impressions</th>
#       <th id="T_0b9f8_level0_col5" class="col_heading level0 col5" >Impressions click-through rate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b9f8_level0_row0" class="row_heading level0 row0" >Comments added</th>
#       <td id="T_0b9f8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0b9f8_row0_col1" class="data row0 col1" >-0.141652</td>
#       <td id="T_0b9f8_row0_col2" class="data row0 col2" >0.484353</td>
#       <td id="T_0b9f8_row0_col3" class="data row0 col3" >0.672014</td>
#       <td id="T_0b9f8_row0_col4" class="data row0 col4" >0.362981</td>
#       <td id="T_0b9f8_row0_col5" class="data row0 col5" >0.224351</td>
#     </tr>
#     <tr>
#       <th id="T_0b9f8_level0_row1" class="row_heading level0 row1" >Average percentage viewed (%)</th>
#       <td id="T_0b9f8_row1_col0" class="data row1 col0" >-0.141652</td>
#       <td id="T_0b9f8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0b9f8_row1_col2" class="data row1 col2" >-0.202818</td>
#       <td id="T_0b9f8_row1_col3" class="data row1 col3" >-0.189377</td>
#       <td id="T_0b9f8_row1_col4" class="data row1 col4" >-0.163310</td>
#       <td id="T_0b9f8_row1_col5" class="data row1 col5" >-0.241190</td>
#     </tr>
#     <tr>
#       <th id="T_0b9f8_level0_row2" class="row_heading level0 row2" >Likes</th>
#       <td id="T_0b9f8_row2_col0" class="data row2 col0" >0.484353</td>
#       <td id="T_0b9f8_row2_col1" class="data row2 col1" >-0.202818</td>
#       <td id="T_0b9f8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0b9f8_row2_col3" class="data row2 col3" >0.958418</td>
#       <td id="T_0b9f8_row2_col4" class="data row2 col4" >0.958740</td>
#       <td id="T_0b9f8_row2_col5" class="data row2 col5" >0.079380</td>
#     </tr>
#     <tr>
#       <th id="T_0b9f8_level0_row3" class="row_heading level0 row3" >Views</th>
#       <td id="T_0b9f8_row3_col0" class="data row3 col0" >0.672014</td>
#       <td id="T_0b9f8_row3_col1" class="data row3 col1" >-0.189377</td>
#       <td id="T_0b9f8_row3_col2" class="data row3 col2" >0.958418</td>
#       <td id="T_0b9f8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0b9f8_row3_col4" class="data row3 col4" >0.923668</td>
#       <td id="T_0b9f8_row3_col5" class="data row3 col5" >0.134627</td>
#     </tr>
#     <tr>
#       <th id="T_0b9f8_level0_row4" class="row_heading level0 row4" >Impressions</th>
#       <td id="T_0b9f8_row4_col0" class="data row4 col0" >0.362981</td>
#       <td id="T_0b9f8_row4_col1" class="data row4 col1" >-0.163310</td>
#       <td id="T_0b9f8_row4_col2" class="data row4 col2" >0.958740</td>
#       <td id="T_0b9f8_row4_col3" class="data row4 col3" >0.923668</td>
#       <td id="T_0b9f8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0b9f8_row4_col5" class="data row4 col5" >-0.015123</td>
#     </tr>
#     <tr>
#       <th id="T_0b9f8_level0_row5" class="row_heading level0 row5" >Impressions click-through rate (%)</th>
#       <td id="T_0b9f8_row5_col0" class="data row5 col0" >0.224351</td>
#       <td id="T_0b9f8_row5_col1" class="data row5 col1" >-0.241190</td>
#       <td id="T_0b9f8_row5_col2" class="data row5 col2" >0.079380</td>
#       <td id="T_0b9f8_row5_col3" class="data row5 col3" >0.134627</td>
#       <td id="T_0b9f8_row5_col4" class="data row5 col4" >-0.015123</td>
#       <td id="T_0b9f8_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot pairwise relationships
sns.pairplot(raw)

# %%
# Show outliers
raw["Views"].nlargest(8)
# Out:
# 2     442044
# 0     265002
# 1      99259
# 6      88223
# 5      59870
# 23     56273
# 3      50270
# 11     42471
# Name: Views, dtype: int64

# %%
# Set upper limit for outliers
q_hi = raw["Views"].quantile(0.99)
q_hi
# Out:
# 255057.41999999963

# %%
# Plot pairwise relationships w/o outliers
sns.pairplot(raw.query("Views < @q_hi"))

# %% [markdown]
# #  Clean up the DataFrame
# ## Simple Example of Pandas method chaining

# %%
# You can chain pandas method like so:
raw.query("Views > 1000").filter(regex="^V", axis="columns").rename(columns={"Video title": "Video_title"})
# Out:
#                                            Video_title Video publish time  \
# 0    How To Send WhatsApp Messages From Excel Using...          19-Dec-20
# 1    How to Create an Excel Data Entry Form in 10 M...          22-May-21
# 2    Turn An Excel Sheet Into An Interactive Dashbo...          11-Sep-21
# 3    Send BULK SMS From Your OWN Number Using EXCEL...          10-Jul-21
# 4    Deploy Your Streamlit Web App on Heroku For Fr...          20-Mar-21
# ..                                                 ...                ...
# 98   How To Create An Interactive Population Pyrami...          24-Dec-20
# 99   Pull Stock Data & Export It To Excel Using Pyt...           6-Mar-21
# 101  Add a snowflake animation to your streamlit we...          24-Dec-21
# 102  How To Create A GUI Program In Python Using Tk...          13-Sep-20
# 104  Create Gauge & Bullet Charts In 3 Seconds Usin...          26-Dec-20
#
#       Views
# 0    265002
# 1     99259
# 2    442044
# 3     50270
# 4     30941
# ..      ...
# 98     2121
# 99     1961
# 101    2087
# 102    1994
# 104    2159
#
# [100 rows x 3 columns]

# %%
# You can also break it down into multiple lines
# By doing so, it makes it easier to debug, as you can comment out line by line
(raw
 .query("Views > 1000")
 .filter(regex="^V", axis="columns")
 .rename(columns={"Video title": "Video_title"})
)
# Out:
#                                            Video_title Video publish time  \
# 0    How To Send WhatsApp Messages From Excel Using...          19-Dec-20
# 1    How to Create an Excel Data Entry Form in 10 M...          22-May-21
# 2    Turn An Excel Sheet Into An Interactive Dashbo...          11-Sep-21
# 3    Send BULK SMS From Your OWN Number Using EXCEL...          10-Jul-21
# 4    Deploy Your Streamlit Web App on Heroku For Fr...          20-Mar-21
# ..                                                 ...                ...
# 98   How To Create An Interactive Population Pyrami...          24-Dec-20
# 99   Pull Stock Data & Export It To Excel Using Pyt...           6-Mar-21
# 101  Add a snowflake animation to your streamlit we...          24-Dec-21
# 102  How To Create A GUI Program In Python Using Tk...          13-Sep-20
# 104  Create Gauge & Bullet Charts In 3 Seconds Usin...          26-Dec-20
#
#       Views
# 0    265002
# 1     99259
# 2    442044
# 3     50270
# 4     30941
# ..      ...
# 98     2121
# 99     1961
# 101    2087
# 102    1994
# 104    2159
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Using Pandas method chaining to clean the DataFrame

# %%
# For reference the initial dataframe
raw.head(3)
# Out:
#        Content                                        Video title  \
# 0  Wn9L1MD_y0Y  How To Send WhatsApp Messages From Excel Using...
# 1  svcv8uub0D0  How to Create an Excel Data Entry Form in 10 M...
# 2  Sb0A9i6d320  Turn An Excel Sheet Into An Interactive Dashbo...
#
#   Video publish time  Comments added  Average percentage viewed (%)  Likes  \
# 0          19-Dec-20             885                          26.36   3057
# 1          22-May-21             207                          28.48   3112
# 2          11-Sep-21             192                          13.14  10175
#
#     Views  Impressions  Impressions click-through rate (%)
# 0  265002      2152704                                6.71
# 1   99259      1069755                                5.70
# 2  442044     11550064                                2.79

# %%
def clean_df(df, views_threshold=500):
    remove_cols = ["Impressions", "Content"]
    remove_nan_values = ["Video publish time", "Impressions click-through rate (%)"]
    return (df
        .drop(labels=remove_cols, axis="columns")
        .dropna(subset=remove_nan_values)
        .pipe(clean_columns)
        .rename(
            columns={
                "impressions_click_through_rate_%": "impressions_ctr_pct",
                "average_percentage_viewed_%": "average_viewed_pct"
            }
        )
        .query("views > @views_threshold")
        .assign(video_publish_time=lambda df_: pd.to_datetime(df_.video_publish_time),
                days_since_published=lambda df_: (pd.to_datetime("today") - df_.video_publish_time).dt.days.astype(int),
                likes_per_day=lambda df_: (df_.likes / df_.days_since_published).round(2),
                likes_to_view_ratio_pct=lambda df_: ((df_.likes / df_.views) * 100).round(2),
                comments_to_view_ratio_pct=lambda df_: ((df_.comments_added / df_.views) * 100).round(2),
               )
    )
df = clean_df(raw)
df.head(3)
# Out:
# 7 column names have been cleaned
#                                          video_title video_publish_time  \
# 0  How To Send WhatsApp Messages From Excel Using...         2020-12-19
# 1  How to Create an Excel Data Entry Form in 10 M...         2021-05-22
# 2  Turn An Excel Sheet Into An Interactive Dashbo...         2021-09-11
#
#    comments_added  average_viewed_pct  likes   views  impressions_ctr_pct  \
# 0             885               26.36   3057  265002                 6.71
# 1             207               28.48   3112   99259                 5.70
# 2             192               13.14  10175  442044                 2.79
#
#    days_since_published  likes_per_day  likes_to_view_ratio_pct  \
# 0                   709           4.31                     1.15
# 1                   555           5.61                     3.14
# 2                   443          22.97                     2.30
#
#    comments_to_view_ratio_pct
# 0                        0.33
# 1                        0.21
# 2                        0.04

# %% [markdown]
# # Plot the data

# %%
# A simple plot
(df
 .set_index("video_publish_time")
 .sort_index()
 .views
 .resample("m")
 .mean()
 .fillna(0)
 .plot(figsize=(16,3))
)
# Out:
# <AxesSubplot:xlabel='video_publish_time'>

# %%
def plot_timeseries(df, columns):
    df = df.set_index("video_publish_time").sort_index()
    fig = px.line(
        df,
        x=df.index,
        y=columns,
        template="simple_white",
        hover_name="video_title",
        title=f"Development: {', '.join(columns).title()}",
    )
    fig.update_layout(hovermode="x unified", margin=dict(l=0, r=0, t=50, b=5))
    return fig

fig = plot_timeseries(df=df, columns=["views", "likes", "comments_added"])
fig.show()
# Out:
# <div>                            <div id="2932a924-0b4f-44a8-9f48-1c1e1a5cdb64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2932a924-0b4f-44a8-9f48-1c1e1a5cdb64")) {                    Plotly.newPlot(                        "2932a924-0b4f-44a8-9f48-1c1e1a5cdb64",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>variable=views<br>video_publish_time=%{x}<br>value=%{y}<extra></extra>","hovertext":["\ud83d\udcc8 How To Get Stock Data In Excel By Using VBA | Step-by-Step Tutorial","\ud83d\udcbb How To Create A GUI In Python Using Tkinter To Display COVID19 Stats | Step-by-Step Tutorial","How To Create An Interactive Gantt Diagram In Python Using Plotly & Excel | Step-by-Step Tutorial","How To Execute A Python Script From Excel Using VBA | Step-by-Step Tutorial [EASY]","How To Create A Treemap & Sunburst Chart In Python Using Plotly & Excel | Tutorial [EASY] \ud83d\udcbb","How To Create An Animated Bar Chart (Bar Race) In Python Using Plotly & Excel | Tutorial [EASY] \ud83d\udcbb","How To Create A Waterfall Chart In Python Using Plotly & Excel | Tutorial [EASY] \ud83d\udcbb","How To Create A Pie Chart In Python Using Plotly & Excel | Tutorial [EASY] \ud83d\udcbb","How To Create A Word Cloud In Python | Tutorial [EASY] \ud83d\udcbb","How to Get Stock Data & Export It To Excel Using Python | Tutorial [EASY] \ud83d\udcbb","How To Create A GUI Program In Python Using Tkinter (EASY) \ud83d\udcbb | Fun Fact Generator","\ud83d\udcc8 How To Create A Candlestick Chart In Python Using Plotly | Tutorial [EASY]","How To Create A Bar Race Animation Using Excel And Python | Tutorial [EASY] \ud83d\udcbb","Excel Template To Create Interactive Waterfall Charts | Combines VBA + Python \ud83d\udcbb","Send WhatsApp Messages From Excel With VBA Using Twilio | Step-by-Step Tutorial \ud83d\udcac","Turn Your Excel Worksheet Into An Exploratory Data Analysis Report In Just 3 Lines Of Python Code \ud83d\udd25","How To Send SMS Messages From Excel With VBA | Step-by-Step Tutorial \ud83d\udcac","How To Automate Excel Using Python | Combine Files & Create Charts \ud83e\udd13","Create Hand Drawn Charts In Excel Using Python (Fast & Easy) | Cutecharts Tutorial \ud83d\udcca","How To Send WhatsApp Messages From Excel Using VBA (Free & Easy) \ud83d\udcf2","How To Create An Interactive Population Pyramid in Python Using Plotly (Fast & Easy)","Create Gauge & Bullet Charts In 3 Seconds Using Excel and Python \ud83d\udc0d | Free Excel Template","Send Daily Push Notifications to Your Phone Using Python | Build A New Year's Resolution BOT (fast)","Quick Tip: Excel VBA Debugging","Install Miniconda (Python) with Jupyter Notebook and Setting Up Virtual Environments on Windows 10","How to Export WhatsApp Chat History to Excel using Python \ud83d\udcf2 (fast & easy) | Android and iOS","Solve Real-World Data Science Tasks in Python | Data Analysis with Pandas & Plotly (Full Tutorial)","How to Run Python in an Open Excel Workbook (EASY) | Combine Excel & Python | xlwings Tutorial","Read Messy & Poorly Structured Excel Files Using Pandas (Python)","Replace Excel Vlookup in Python Using Pandas (fast & easy) | Pandas Merge Tutorial","Pull Stock Data & Export It To Excel Using Python #shorts","Turn Your Excel File Into A Web App With Python (fast & easy) | Streamlit Tutorial","Deploy Your Streamlit Web App on Heroku For Free (fast & easy)","Build a Dividend & Portfolio Tracker in Excel by using Python [Free Template]","Build a Weather App in Excel by using Python","How to Merge Multiple PDF Files in Excel Using Python (fast & easy)","What is this channel all about...","How To Create Pandas Dataframe From Clipboard #Shorts","Automating Word Documents from Excel Using Python | \u2018docxtpl\u2019 Tutorial","Create A Liquid (W ...

# %% [markdown]
# ## Barchart: Top X Videos

# %%
def plot_column(df, column, top_values=10, color="#d33682"):
    df = df.nlargest(top_values, columns=column).sort_values(by=column)
    title = f"{column.replace('_',' ').replace('pct','%').title()} - Top {top_values} videos"
    mean = df[column].mean()
    median = df[column].median()

    fig = px.bar(
        df,
        x=column,
        y="video_title",
        orientation="h",
        title=title,
        color_discrete_sequence=[color] * top_values,
        template="plotly_white",
        text=column,
    )
    # add a vertical "mean" line
    fig.add_vline(
        x=mean,
        line_color="gray",
        line_width=3,
        opacity=1,
        line_dash="dot",
        annotation_position="top",
        annotation=dict(text="mean", font_size=12, font_color="gray"),
    )
    # add a vertical "mediam" line
    fig.add_vline(
        x=median,
        line_color="salmon",
        line_width=3,
        opacity=1,
        line_dash="dot",
        annotation_position="bottom",
        annotation=dict(text="median", font_size=12, font_color="salmon"),
    )
    fig.update_layout(
        plot_bgcolor="rgba(0,0,0,0)",
        yaxis=(dict(showgrid=False, title=None)),
        xaxis=(dict(showgrid=False, title=None, showticklabels=False)),
        margin=dict(l=0, r=0, t=50, b=5),
    )
    return fig

# %%
# print all numeric columns
df.select_dtypes('number').columns.to_list()
# Out:
# ['comments_added',
#  'average_viewed_pct',
#  'likes',
#  'views',
#  'impressions_ctr_pct',
#  'days_since_published',
#  'likes_per_day',
#  'likes_to_view_ratio_pct',
#  'comments_to_view_ratio_pct']

# %%
fig = plot_column(df=df, column="likes_to_view_ratio_pct", top_values=8)
fig.show()
# Optional: Export the chart to a standalone HTML file
fig.write_html("chart.html")
# Out:
# <div>                            <div id="bfe41dc0-0b6f-464c-8707-3f778c7f25b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfe41dc0-0b6f-464c-8707-3f778c7f25b3")) {                    Plotly.newPlot(                        "bfe41dc0-0b6f-464c-8707-3f778c7f25b3",                        [{"alignmentgroup":"True","hovertemplate":"likes_to_view_ratio_pct=%{text}<br>video_title=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#d33682","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[4.9,5.19,5.31,5.88,6.03,6.34,6.5,8.72],"textposition":"auto","x":[4.9,5.19,5.31,5.88,6.03,6.34,6.5,8.72],"xaxis":"x","y":["Automate Emails Using Python! Build An Automatic Payment Reminder & Schedule Your Scripts Online","Build A Digital Resume Using Python & Streamlit","Create Hand Drawn Charts In Excel Using Python (Fast & Easy) | Cutecharts Tutorial \ud83d\udcca","5 Little Known Pandas Features \ud83e\udd13","The EASIEST way to load multiple EXCEL sheets in PANDAS","Deploy Your Streamlit App To Render (Free Heroku Alternative)","How To Create Pandas Dataframe From Clipboard #Shorts","4 Pandas Functions That I Wish I Knew Earlier"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555 ...

# %% [markdown]
# # Wordcloud: Video Titles

# %%
def generate_wordcloud(df, column, max_font_size=60, collocations=False):
    text = df[column].values
    return WordCloud(max_font_size=max_font_size, collocations=collocations).generate(str(text))   

wordcloud = generate_wordcloud(df, "video_title")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
